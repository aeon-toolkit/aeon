# %% [markdown]
# ## Series

# %%
from aeon.datasets import load_airline
from aeon.visualisation import plot_correlations, plot_lags, plot_series

# %%
airline = load_airline()

_ = plot_series(airline)

# %%
airline_train, airline_test = airline[:-24], airline[-24:]
airline_mid = airline[60:96] + 100

_ = plot_series(airline_train, airline_test, airline_mid)

# %%
_ = plot_lags(airline, lags=2)

# %%
_ = plot_lags(airline, lags=[1, 2, 3])

# %%
_ = plot_correlations(airline)

# %% [markdown]
# ## Collection

# %%
from aeon.datasets import load_arrow_head
from aeon.visualisation import plot_collection_by_class, plot_series_collection

# %%
arrowhead_X, arrowhead_y = load_arrow_head()

_ = plot_series_collection(arrowhead_X[:3])

# %%
_ = plot_series_collection(arrowhead_X[:9], arrowhead_y[:9])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 _ = plot_series_collection(arrowhead_X[:9], arrowhead_y[:9])
#
# File D:\CMP_Machine_Learning\Repositories\aeon\aeon\visualisation\series\_collections.py:44, in plot_series_collection(X, y)
#      42     handles, labels = ax.get_legend_handles_labels()
#      43     label_handle_map = dict(zip(labels, handles))
# ---> 44     ax.legend([label_handle_map[str(label)] for label in unique_labels],
#      45               unique_labels)
#      47 return fig, ax
#
# File D:\CMP_Machine_Learning\Repositories\aeon\aeon\visualisation\series\_collections.py:44, in <listcomp>(.0)
#      42     handles, labels = ax.get_legend_handles_labels()
#      43     label_handle_map = dict(zip(labels, handles))
# ---> 44     ax.legend([label_handle_map[str(label)] for label in unique_labels],
#      45               unique_labels)
#      47 return fig, ax
#
# KeyError: '0'

# %%
_ = plot_collection_by_class(arrowhead_X[:9], arrowhead_y[:9])

# %% [markdown]
# ## Learning Task
#
# ### Forecasting

# %% [markdown]
#     "plot_windows",
#     "plot_time_series_with_change_points",
#     "plot_time_series_with_profiles",

# %% [markdown]
# ### Segmentation
